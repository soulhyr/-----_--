# %%
import pandas as pd

# %%
# pandas library 설치하기
# 설치가 되어 있다면 이 셀은 실행하지 않아도 됨.
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 11.6/11.6 MB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 345.4/345.4 kB 4.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 15.8/15.8 MB 2.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 505.5/505.5 kB 2.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pandas 임폴트하기
import pandas as pd

# %%
# 한글 폰트 설치

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'rm'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 현재 위치 확인하기
print("매직 명령어 실행!!")
print("한글테스트")
# !dir
# !ls
# Out:
# 매직 명령어 실행!!
# 한글테스트
#  C ����̺��� �������� �̸��� �����ϴ�.
#  ���� �Ϸ� ��ȣ: D2D3-6E29
#
#  c:\Users\Richard\Documents\ICT �̳뺣�̼� ����\�����ͺм�_�߱�\01 1����_���̽� �� ������\������ ���͸�
#
# 2024-06-12  ���� 08:45    <DIR>          .
# 2024-06-12  ���� 08:12    <DIR>          ..
# 2024-06-13  ���� 09:54            35,896 1_���Ӥ��̤����Ǥ����Ƥ�����_���������Ǥ���.ipynb
# 2024-06-12  ���� 08:12           354,862 1_���Ĥ��Ӥ��ä���_���Ӥ��̤����Ǥ�����1.pdf
# 2024-06-12  ���� 09:54            10,232 2_���Ӥ��̤����Ǥ����Ƥ�����_���Ӥ����Ѥ�.ipynb
# 2024-06-12  ���� 08:12           582,618 2_���Ĥ��Ӥ��ä���_���Ӥ��̤����Ǥ�����2.pdf
# 2024-06-12  ���� 08:12         1,256,735 3_���Ȥ����Ф�����_���̤��Ǥ����Ǥ�����.pdf
# 2024-06-12  ���� 08:12         1,288,411 4_���ä����Ф��̤����Ǥ���_���̤����Ӥ����Ѥ����������ä�����.pdf
# 2024-06-12  ���� 08:12           880,739 5_���Ӥ����ʤ��̤�����.pdf
# 2024-06-12  ���� 09:00    <DIR>          datasets
#                7�� ����           4,409,493 ����Ʈ
# ...

# %%
# 데이터 불러오기 및 5줄 출력
df = pd.read_csv('./datasets/1_kaggle_supply_chain_data.csv')
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
# 데이터 타입 확인하기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
# 변수의 개수 확인하기
print(len(df.columns))
# 변수 목록 확인하기
df.columns
# Out:
# 24
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
# 기술 통계량 확인하기 - 수치형 데이터에 한해서 보여줌.
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
# 기술 통계량 확인하기 - 범주형 데이터
df.describe(include='object')
# Out:
#        Product type   SKU Customer demographics Shipping carriers  \
# count           100   100                   100               100
# unique            3   100                     4                 3
# top        skincare  SKU0               Unknown         Carrier B
# freq             40     1                    31                43
#
#        Supplier name Location Inspection results Transportation modes   Routes
# count            100      100                100                  100      100
# unique             5        5                  3                    4        3
# top       Supplier 1  Kolkata            Pending                 Road  Route A
# freq              27       25                 41                   29       43

# %%
# 기술 통계량 csv 파일로 저장하기
df.describe(include='object').to_csv('./datasets/result.csv', index=False)

# %%
# 저장한 csv 파일 불러와서 확인하기
df2 = pd.read_csv('./datasets/result.csv')
df2
# Out:
#   Product type   SKU Customer demographics Shipping carriers Supplier name  \
# 0          100   100                   100               100           100
# 1            3   100                     4                 3             5
# 2     skincare  SKU0               Unknown         Carrier B    Supplier 1
# 3           40     1                    31                43            27
#
#   Location Inspection results Transportation modes   Routes
# 0      100                100                  100      100
# 1        5                  3                    4        3
# 2  Kolkata            Pending                 Road  Route A
# 3       25                 41                   29       43
